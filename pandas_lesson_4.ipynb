# %% [markdown]
# <a href="https://colab.research.google.com/github/adityagavandi2003/Pandas-Learning/blob/main/pandas_lesson_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lesson 4 — Basic Operations & Aggregations in Pandas**
#
# ---

# %%
import pandas as pd

data = {
    "Product": ["Apples", "Bananas", "Oranges", "Apples", "Bananas"],
    "Quantity": [10, 5, 8, 7, 3],
    "Price": [50, 20, 30, 50, 20]
}

df = pd.DataFrame(data)
df["Sales"] = df["Quantity"] * df["Price"]
print(df)
# Out:
#    Product  Quantity  Price  Sales
# 0   Apples        10     50    500
# 1  Bananas         5     20    100
# 2  Oranges         8     30    240
# 3   Apples         7     50    350
# 4  Bananas         3     20     60

# %% [markdown]
# 1. Sorting

# %%
df.sort_values("Sales", ascending=False)
# Out:
#    Product  Quantity  Price  Sales
# 0   Apples        10     50    500
# 3   Apples         7     50    350
# 2  Oranges         8     30    240
# 1  Bananas         5     20    100
# 4  Bananas         3     20     60

# %% [markdown]
# 2. Aggregations (single column)

# %%
max_quantity = df['Quantity'].max() # find max quantity
print("Max Quantity",max_quantity)
min_quantity = df["Quantity"].min() # find min quantity
print("Min Quantity",min_quantity)
sum_quantity = df["Quantity"].sum() # find sum quantity
print("Sum Quantity",sum_quantity)
mean_quantity = df['Quantity'].mean() # find mean quantity
print("Mean",mean_quantity)
# Out:
# Max Quantity 10
# Min Quantity 3
# Sum Quantity 33
# Mean 6.6

# %% [markdown]
# 3. Multiple Aggregations

# %%
df[["Quantity","Sales"]].agg(["sum","mean"])
# Out:
#       Quantity   Sales
# sum       33.0  1250.0
# mean       6.6   250.0

# %% [markdown]
# 4. GroupBy

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Bananas    160
# Oranges    240
# Apples     850
# Name: Sales, dtype: int64

# %% [markdown]
# Sort data in descending order

# %%
df.groupby("Product")["Sales"].sum().sort_values(ascending=False)
# Out:
# Product
# Apples     850
# Oranges    240
# Bananas    160
# Name: Sales, dtype: int64

# %% [markdown]
# 5. Value Counts

# %%
df["Product"].value_counts()
# Out:
# Product
# Apples     2
# Bananas    2
# Oranges    1
# Name: count, dtype: int64

# %% [markdown]
# 6. Renaming Columns

# %%
df.rename(columns={"Sales":"Total_Sales"})
# Out:
#    Product  Quantity  Price  Total_Sales
# 0   Apples        10     50          500
# 1  Bananas         5     20          100
# 2  Oranges         8     30          240
# 3   Apples         7     50          350
# 4  Bananas         3     20           60

# %% [markdown]
# **Practice**
#
# ---

# %% [markdown]
# 1. Sort the DataFrame by Sales descending.

# %%
df.sort_values("Total_Sales",ascending=False)
# Out:
#    Product  Quantity  Price  Total_Sales
# 0   Apples        10     50          500
# 3   Apples         7     50          350
# 2  Oranges         8     30          240
# 1  Bananas         5     20          100
# 4  Bananas         3     20           60

# %% [markdown]
# 2. What is the total Quantity sold?

# %%
print("Total Quantity Sold:",df["Quantity"].sum())
# Out:
# Total Quantity Sold: 33

# %% [markdown]
# 3. What is the average Sales per transaction?

# %%
print("Avg. sales per transaction:",df["Total_Sales"].mean())
# Out:
# Avg. sales per transaction: 250.0

# %% [markdown]
# 4. Show the total Sales per Product.

# %%
df.groupby("Product")["Total_Sales"].sum()
# Out:
# Product
# Apples     850
# Bananas    160
# Oranges    240
# Name: Total_Sales, dtype: int64

# %% [markdown]
# 5. For each Product, show both sum of Quantity and average Price.

# %%
df.groupby("Product").agg({
    "Quantity":"sum",
    "Total_Sales":"mean"
})
# Out:
#          Quantity  Total_Sales
# Product
# Apples         17        425.0
# Bananas         8         80.0
# Oranges         8        240.0
